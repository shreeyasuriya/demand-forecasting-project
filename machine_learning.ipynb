# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score


from xgboost import XGBRegressor

import pickle

# %%
df=pd.read_csv("demand_forecasting.csv")

# %%
df
# Out:
#              Date Store ID Product ID  ... Seasonality Epidemic  Demand
# 0      2022-01-01     S001      P0001  ...      Winter        0     115
# 1      2022-01-01     S001      P0002  ...      Winter        0     229
# 2      2022-01-01     S001      P0003  ...      Winter        0     157
# 3      2022-01-01     S001      P0004  ...      Winter        0      52
# 4      2022-01-01     S001      P0005  ...      Winter        0      59
# ...           ...      ...        ...  ...         ...      ...     ...
# 75995  2024-01-30     S005      P0016  ...      Winter        0      64
# 75996  2024-01-30     S005      P0017  ...      Winter        0     137
# 75997  2024-01-30     S005      P0018  ...      Winter        0      68
# 75998  2024-01-30     S005      P0019  ...      Winter        0      84
# 75999  2024-01-30     S005      P0020  ...      Winter        0      73
#
# [76000 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Store ID', 'Product ID', 'Category', 'Region',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Price', 'Discount',
#        'Weather Condition', 'Promotion', 'Competitor Pricing', 'Seasonality',
#        'Epidemic', 'Demand'],
#       dtype='str')

# %%
features = [
    "Price",
    "Discount",
    "Inventory Level",
    "Promotion",
    "Competitor Pricing",
    "Category"
]

# %%
features
# Out:
# ['Price',
#  'Discount',
#  'Inventory Level',
#  'Promotion',
#  'Competitor Pricing',
#  'Category']

# %%
target = "Demand"

# %%
X = df[features].copy()

# %%
X
# Out:
#         Price  Discount  ...  Competitor Pricing     Category
# 0       72.72         5  ...               85.73  Electronics
# 1       80.16        15  ...               92.02     Clothing
# 2       62.94        10  ...               60.08     Clothing
# 3       87.63        10  ...               85.19  Electronics
# 4       54.41         0  ...               51.63    Groceries
# ...       ...       ...  ...                 ...          ...
# 75995   29.80         5  ...               32.23         Toys
# 75996   42.92         5  ...               40.73         Toys
# 75997   17.81        10  ...               19.41     Clothing
# 75998  151.72         0  ...              143.71    Furniture
# 75999   25.78        10  ...               29.32         Toys
#
# [76000 rows x 6 columns]

# %%
y = df[target]

# %%
y
# Out:
# 0        115
# 1        229
# 2        157
# 3         52
# 4         59
#         ...
# 75995     64
# 75996    137
# 75997     68
# 75998     84
# 75999     73
# Name: Demand, Length: 76000, dtype: int64

# %%
label_encoders = {}

categorical_cols = X.select_dtypes(include = "str").columns

# %%
categorical_cols
# Out:
# Index(['Category'], dtype='str')

# %%
for col in categorical_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le

# %%
label_encoders
# Out:
# {'Category': LabelEncoder()}

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X
# Out:
#         Price  Discount  ...  Competitor Pricing  Category
# 0       72.72         5  ...               85.73         1
# 1       80.16        15  ...               92.02         0
# 2       62.94        10  ...               60.08         0
# 3       87.63        10  ...               85.19         1
# 4       54.41         0  ...               51.63         3
# ...       ...       ...  ...                 ...       ...
# 75995   29.80         5  ...               32.23         4
# 75996   42.92         5  ...               40.73         4
# 75997   17.81        10  ...               19.41         0
# 75998  151.72         0  ...              143.71         2
# 75999   25.78        10  ...               29.32         4
#
# [76000 rows x 6 columns]

# %%
xgb = XGBRegressor(objective = "reg:squarederror", n_jobs = -1)

# %%
param_dict = {
    "n_estimators" : [200, 300, 500],
    "max_depth" : [3, 4, 6, 8],
    "learning_rate" : [0.01, 0.05, 0.1],
    "subsample" : [0.7, 0.8, 1.0],
    "colsample_bytree" : [0.7, 0.8, 1.0],
    "min_child_weight" : [1, 3, 5]
    }

# %%
random_search = RandomizedSearchCV(
    estimator = xgb,
    param_distributions = param_dict,
    n_iter = 25,
    scoring = "neg_mean_absolute_error",
    cv = 3,
    verbose = 1,
    n_jobs = -1
)

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraint...
#                                           monotone_constraints=None,
#                                           multi_strategy=None,
#                                           n_estimators=None, n_jobs=-1,
#                                           num_parallel_tree=None, ...),
#                    n_iter=25, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.7, 0.8, 1.0],
#                                         'learning_rate': [0.01, 0.05, 0.1],
#                                         'max_depth': [3, 4, 6, 8],
#                                         'min_child_weight': [1, 3, 5],
#                                         'n_estimators': [200, 300, 500],
#                                         'subsample': [0.7, 0.8, 1.0]},
#                    scoring='neg_mean_absolute_error', verbose=1)

# %%
random_search.best_params_
# Out:
# {'subsample': 0.7,
#  'n_estimators': 300,
#  'min_child_weight': 5,
#  'max_depth': 8,
#  'learning_rate': 0.05,
#  'colsample_bytree': 1.0}

# %%
best_model = random_search.best_estimator_

# %%
y_pred =best_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(rmse)
# Out:
# 35.67029569708089

# %%
best_model.feature_importances_
# Out:
# array([0.08541793, 0.02911485, 0.027779  , 0.5553403 , 0.03170793,
#        0.27064   ], dtype=float32)

# %%
feature_importance = pd.Series(
    best_model.feature_importances_,
    index = X.columns
).sort_values(ascending = False)

# %%
feature_importance
# Out:
# Promotion             0.555340
# Category              0.270640
# Price                 0.085418
# Competitor Pricing    0.031708
# Discount              0.029115
# Inventory Level       0.027779
# dtype: float32

# %%
feature_importance.plot(kind = "bar" , title = "Feature Importance")
# Out:
# <Axes: title={'center': 'Feature Importance'}>

# %%
with open("label_encoders.pkl","wb") as f:
    pickle.dump(label_encoders, f)

# %%
with open("xgboost_demand_model.pkl", "wb") as f:
    pickle.dump(best_model, f)
